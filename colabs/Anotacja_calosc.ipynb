# %%
import random
import pandas as pd
import numpy as np
import os
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
NASA = pd.read_csv('/content/drive/MyDrive/sampled_NASA_200k.csv')

# %%
selected_columns = ["lon", "lat"]
NASA_coordinates = NASA[selected_columns]

# %%
NASA_coordinates = NASA_coordinates.drop_duplicates(subset=["lat", "lon"])

# %%
random.seed(1)
random_sample = random.sample(range(0, len(NASA_coordinates) - 1), 100)

# %%
NASA_sample = NASA_coordinates.iloc[random_sample, :].copy()

# %%
NASA_sample
# Out:
#              lon      lat
# 20042   -98.4375  49.0625
# 8822    -84.4375  51.9375
# 43941  -100.5625  47.0625
# 17257  -104.6875  48.8125
# 145584  -95.1875  36.5625
# ...          ...      ...
# 33230  -103.1875  48.4375
# 100635  -92.1875  40.4375
# 7788   -103.9375  44.3125
# 133844  -75.0625  41.9375
# 75134  -110.8125  48.1875
#
# [100 rows x 2 columns]

# %%
NASA_sample.to_csv('/content/drive/MyDrive/NASA_sample.csv', index=False, sep=';')

# %%
NASA_sample_an = pd.read_csv('/content/drive/MyDrive/BigMess/NASA/NASA_sample_an.csv', sep=';')

# %%
NASA_sample_an
# Out:
#          lon      lat  pustynia  step
# 0   -98.4375  49.0625         0     0
# 1   -84.4375  51.9375         0     0
# 2  -100.5625  47.0625         0     0
# 3  -104.6875  48.8125         0     0
# 4   -95.1875  36.5625         0     0
# ..       ...      ...       ...   ...
# 95 -103.1875  48.4375         0     0
# 96  -92.1875  40.4375         0     0
# 97 -103.9375  44.3125         0     0
# 98  -75.0625  41.9375         0     0
# 99 -110.8125  48.1875         0     0
#
# [100 rows x 4 columns]

# %%
np.random.seed(1)
x = np.setdiff1d(np.arange(0, len(NASA_coordinates)), random_sample)
random_sample_2 = np.random.choice(x, size = 400, replace = False)

# %%
NASA_sample_2 = NASA_coordinates.iloc[random_sample_2, :].copy()

# %%
NASA_sample_2
# Out:
#              lon      lat
# 190123  -95.0625  39.5625
# 84502   -86.3125  31.3125
# 73081   -84.1875  49.1875
# 49508   -87.5625  31.9375
# 102066 -101.4375  27.5625
# ...          ...      ...
# 101109 -115.0625  30.3125
# 16271   -96.1875  42.6875
# 182379 -105.5625  28.0625
# 136009  -71.8125  46.5625
# 12281   -81.9375  27.4375
#
# [400 rows x 2 columns]

# %%
NASA_sample_2.to_csv('/content/drive/MyDrive/NASA_sample_2.csv', index=False, sep=';')

# %%
NASA_sample_an_2 = pd.read_csv('/content/drive/MyDrive/BigMess/NASA/NASA_sample_an_2.csv', sep=';')

# %%
NASA_sample_an_2
# Out:
#           lon      lat  pustynia  step
# 0    -95.0625  39.5625         0     0
# 1    -86.3125  31.3125         0     0
# 2    -84.1875  49.1875         0     0
# 3    -87.5625  31.9375         0     0
# 4   -101.4375  27.5625         0     1
# ..        ...      ...       ...   ...
# 395 -115.0625  30.3125         1     0
# 396  -96.1875  42.6875         0     0
# 397 -105.5625  28.0625         1     0
# 398  -71.8125  46.5625         0     0
# 399  -81.9375  27.4375         0     0
#
# [400 rows x 4 columns]

# %%
NASA_an = pd.concat([NASA_sample_an, NASA_sample_an_2], ignore_index=True)

# %%
NASA_an
# Out:
#           lon      lat  pustynia  step
# 0    -98.4375  49.0625         0     0
# 1    -84.4375  51.9375         0     0
# 2   -100.5625  47.0625         0     0
# 3   -104.6875  48.8125         0     0
# 4    -95.1875  36.5625         0     0
# ..        ...      ...       ...   ...
# 495 -115.0625  30.3125         1     0
# 496  -96.1875  42.6875         0     0
# 497 -105.5625  28.0625         1     0
# 498  -71.8125  46.5625         0     0
# 499  -81.9375  27.4375         0     0
#
# [500 rows x 4 columns]

# %%
NASA_an['pustynia'].sum()
# Out:
# 69

# %%
NASA_an['step'].sum()
# Out:
# 87

# %%
NASA_an.to_csv('/content/drive/MyDrive/BigMess/NASA/NASA_an.csv', index=False, sep=';')
